# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = 10,10  # that's default image size for this 
#pylab.rcParams['figure.dpi']=32
# %load_ext autoreload
# %autoreload 2
#run txtFiletoHistogram.py
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#%%timeit -n4 -r1
# %run dirAnalyzerDemo.py
# Out:
# Centerline extraction time for file T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png is 0.946287
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png centreline + Angle estimation time at scale 0 =(mSize 36, nBands 18) is 4.332982
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png centreline + Angle estimation time at scale 1 =(mSize 54, nBands 18) is 5.268529
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png centreline + Angle estimation time at scale 2 =(mSize 72, nBands 18) is 5.55746
# Centerline extraction time for file T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png is 0.510822
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png centreline + Angle estimation time at scale 0 =(mSize 36, nBands 18) is 2.110439
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png centreline + Angle estimation time at scale 1 =(mSize 54, nBands 18) is 2.382161
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png centreline + Angle estimation time at scale 2 =(mSize 72, nBands 18) is 2.387823
# Centerline extraction time for file T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png is 0.540423
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png centreline + Angle estimation time at scale 0 =(mSize 36, nBands 18) is 2.628425
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png centreline + Angle estimation time at scale 1 =(mSize 54, nBands 18) is 3.069325
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png centreline + Angle estimation time at scale 2 =(mSize 72, nBands 18) is 2.865424
# Centerline extraction time for file T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png is 0.496034
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png centreline + Angle estimation time at scale 0 =(mSize 36, nBands 18) is 2.917976
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png centreline + Angle estimation time at scale 1 =(mSize 54, nBands 18) is 3.452415
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png centreline + Angle estimation time at scale 2 =(mSize 72, nBands 18) is 3.328601
# Total number of pixels on the centerline is = 1429
# The circular mean and variance are -46.6193415428 and 0.435041063945 respectively.
# Total number of pixels on the centerline is = 1429
# The circular mean and variance are -44.650588962 and 0.386796626843 respectively.
# Total number of pixels on the centerline is = 1429
# The circular mean and variance are -44.3780590159 and 0.342640234333 respectively.
# Total number of pixels on the centerline is = 1189
# The circular mean and variance are -78.3810025938 and 0.290572844592 respectively.
# Total number of pixels on the centerline is = 1189
# The circular mean and variance are -77.089030543 and 0.304591220714 respectively.
# Total number of pixels on the centerline is = 1189
# The circular mean and variance are -74.1919323083 and 0.306721713638 respectively.
# Total number of pixels on the centerline is = 740
# The circular mean and variance are -44.4790197358 and 0.209571469084 respectively.
# Total number of pixels on the centerline is = 740
# The circular mean and variance are -44.5749851677 and 0.159250180464 respectively.
# Total number of pixels on the centerline is = 740
# The circular mean and variance are -44.1787899376 and 0.124729461226 respectively.
# Total number of pixels on the centerline is = 695
# The circular mean and variance are -55.7997383121 and 0.819393413287 respectively.
# Total number of pixels on the centerline is = 695
# The circular mean and variance are -58.2182957862 and 0.767904680482 respectively.
# Total number of pixels on the centerline is = 695
# The circular mean and variance are -53.0236244157 and 0.765621201015 respectively.
# Total probability = 1.0
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure klDiv calculation time at scale 0 =(mSize 36, nBands 18) is 0.000810999999999
# At scale 0, bands = 18, size = 36  measure based on function klDiv is 2.68638876375
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure klDiv calculation time at scale 1 =(mSize 54, nBands 18) is 0.000743
# At scale 1, bands = 18, size = 54  measure based on function klDiv is 2.78206351673
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure klDiv calculation time at scale 2 =(mSize 72, nBands 18) is 0.000731999999999
# At scale 2, bands = 18, size = 72  measure based on function klDiv is 3.02515659185
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure klDiv calculation time at scale 0 =(mSize 36, nBands 18) is 0.000982999999998
# At scale 0, bands = 18, size = 36  measure based on function klDiv is 3.30670837817
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure klDiv calculation time at scale 1 =(mSize 54, nBands 18) is 0.000901999999996
# At scale 1, bands = 18, size = 54  measure based on function klDiv is 3.08726661642
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure klDiv calculation time at scale 2 =(mSize 72, nBands 18) is 0.001548
# At scale 2, bands = 18, size = 72  measure based on function klDiv is 3.02383919054
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure klDiv calculation time at scale 0 =(mSize 36, nBands 18) is 0.000934999999998
# At scale 0, bands = 18, size = 36  measure based on function klDiv is 3.16363586191
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure klDiv calculation time at scale 1 =(mSize 54, nBands 18) is 0.000737999999998
# At scale 1, bands = 18, size = 54  measure based on function klDiv is 3.03548414249
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure klDiv calculation time at scale 2 =(mSize 72, nBands 18) is 0.000719000000004
# At scale 2, bands = 18, size = 72  measure based on function klDiv is 2.62589952868
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure klDiv calculation time at scale 0 =(mSize 36, nBands 18) is 0.000917000000001
# At scale 0, bands = 18, size = 36  measure based on function klDiv is 3.11021567881
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure klDiv calculation time at scale 1 =(mSize 54, nBands 18) is 0.000731000000002
# At scale 1, bands = 18, size = 54  measure based on function klDiv is 2.953540595
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure klDiv calculation time at scale 2 =(mSize 72, nBands 18) is 0.000723000000001
# At scale 2, bands = 18, size = 72  measure based on function klDiv is 2.99507053483
# [[2.6863887637469421, 2.7820635167302648, 3.0251565918525207], [3.3067083781662232, 3.0872666164212927, 3.0238391905408672], [3.1636358619055791, 3.0354841424943153, 2.6258995286807196], [3.1102156788098489, 2.9535405950003644, 2.9950705348332041]]
# Total probability = 1.0
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure emdDist calculation time at scale 0 =(mSize 36, nBands 18) is 0.00327100000001
# At scale 0, bands = 18, size = 36  measure based on function emdDist is 23.5816807698
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure emdDist calculation time at scale 1 =(mSize 54, nBands 18) is 0.003542
# At scale 1, bands = 18, size = 54  measure based on function emdDist is 21.1953214555
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure emdDist calculation time at scale 2 =(mSize 72, nBands 18) is 0.002845
# At scale 2, bands = 18, size = 72  measure based on function emdDist is 18.9070504059
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure emdDist calculation time at scale 0 =(mSize 36, nBands 18) is 0.00328200000001
# At scale 0, bands = 18, size = 36  measure based on function emdDist is 18.0577846224
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure emdDist calculation time at scale 1 =(mSize 54, nBands 18) is 0.003123
# At scale 1, bands = 18, size = 54  measure based on function emdDist is 18.702096249
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure emdDist calculation time at scale 2 =(mSize 72, nBands 18) is 0.002784
# At scale 2, bands = 18, size = 72  measure based on function emdDist is 18.1723675358
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure emdDist calculation time at scale 0 =(mSize 36, nBands 18) is 0.004033
# At scale 0, bands = 18, size = 36  measure based on function emdDist is 14.5320093798
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure emdDist calculation time at scale 1 =(mSize 54, nBands 18) is 0.003858
# At scale 1, bands = 18, size = 54  measure based on function emdDist is 12.5715489663
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure emdDist calculation time at scale 2 =(mSize 72, nBands 18) is 0.003674
# At scale 2, bands = 18, size = 72  measure based on function emdDist is 10.7737499128
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure emdDist calculation time at scale 0 =(mSize 36, nBands 18) is 0.002861
# At scale 0, bands = 18, size = 36  measure based on function emdDist is 37.5074865036
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure emdDist calculation time at scale 1 =(mSize 54, nBands 18) is 0.003572
# At scale 1, bands = 18, size = 54  measure based on function emdDist is 35.9390403021
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure emdDist calculation time at scale 2 =(mSize 72, nBands 18) is 0.00283899999999
# At scale 2, bands = 18, size = 72  measure based on function emdDist is 35.7232762158
# [[23.581680769800027, 21.195321455520027, 18.90705040587003], [18.057784622400025, 18.702096248970026, 18.172367535780026], [14.532009379830024, 12.57154896627002, 10.773749912760023], [37.50748650360003, 35.939040302070026, 35.72327621583003]]
# Normalized by 45 EMD score are
# [[ 0.52403735  0.47100714  0.42015668]
#  [ 0.4012841   0.41560214  0.40383039]
#  [ 0.32293354  0.27936775  0.23941666]
#  [ 0.8334997   0.79864534  0.79385058]]
# Total probability = 1.0
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure L2Dist calculation time at scale 0 =(mSize 36, nBands 18) is 0.000678000000001
# At scale 0, bands = 18, size = 36  measure based on function L2Dist is 0.766305736853
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure L2Dist calculation time at scale 1 =(mSize 54, nBands 18) is 0.000503000000002
# At scale 1, bands = 18, size = 54  measure based on function L2Dist is 0.776006075171
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure L2Dist calculation time at scale 2 =(mSize 72, nBands 18) is 0.000476999999997
# At scale 2, bands = 18, size = 72  measure based on function L2Dist is 0.815607463761
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure L2Dist calculation time at scale 0 =(mSize 36, nBands 18) is 0.000521999999997
# At scale 0, bands = 18, size = 36  measure based on function L2Dist is 0.85666441568
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure L2Dist calculation time at scale 1 =(mSize 54, nBands 18) is 0.000484
# At scale 1, bands = 18, size = 54  measure based on function L2Dist is 0.818410826345
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure L2Dist calculation time at scale 2 =(mSize 72, nBands 18) is 0.000473999999997
# At scale 2, bands = 18, size = 72  measure based on function L2Dist is 0.812726769325
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure L2Dist calculation time at scale 0 =(mSize 36, nBands 18) is 0.000532
# At scale 0, bands = 18, size = 36  measure based on function L2Dist is 0.819042443737
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure L2Dist calculation time at scale 1 =(mSize 54, nBands 18) is 0.000479000000006
# At scale 1, bands = 18, size = 54  measure based on function L2Dist is 0.785194082324
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure L2Dist calculation time at scale 2 =(mSize 72, nBands 18) is 0.000473
# At scale 2, bands = 18, size = 72  measure based on function L2Dist is 0.698413188774
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure L2Dist calculation time at scale 0 =(mSize 36, nBands 18) is 0.000565000000002
# At scale 0, bands = 18, size = 36  measure based on function L2Dist is 0.858125683135
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure L2Dist calculation time at scale 1 =(mSize 54, nBands 18) is 0.000480000000003
# At scale 1, bands = 18, size = 54  measure based on function L2Dist is 0.834659451559
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure L2Dist calculation time at scale 2 =(mSize 72, nBands 18) is 0.000474999999994
# At scale 2, bands = 18, size = 72  measure based on function L2Dist is 0.834403610537
# [[0.76630573685299253, 0.77600607517071329, 0.8156074637605224], [0.8566644156797496, 0.81841082634511497, 0.81272676932538646], [0.81904244373676349, 0.78519408232425447, 0.69841318877446334], [0.85812568313539006, 0.83465945155897114, 0.83440361053702317]]
