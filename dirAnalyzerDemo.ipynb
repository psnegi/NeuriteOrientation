# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = 10,10  # that's default image size for this 
#pylab.rcParams['figure.dpi']=32
# %load_ext autoreload
# %autoreload 2
#run txtFiletoHistogram.py
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#%%timeit -n4 -r1
# %run dirAnalyzerDemo.py
# Out:
# Centerline extraction time for file T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png is 0.950529
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png centreline + Angle estimation time at scale 0 =(mSize 36, nBands 18) is 22.4298
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png centreline + Angle estimation time at scale 1 =(mSize 54, nBands 18) is 47.373889
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png centreline + Angle estimation time at scale 2 =(mSize 72, nBands 18) is 88.793388
# Centerline extraction time for file T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png is 0.411087
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png centreline + Angle estimation time at scale 0 =(mSize 36, nBands 18) is 8.93002
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png centreline + Angle estimation time at scale 1 =(mSize 54, nBands 18) is 18.985686
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png centreline + Angle estimation time at scale 2 =(mSize 72, nBands 18) is 35.7085
# Centerline extraction time for file T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png is 0.491428
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png centreline + Angle estimation time at scale 0 =(mSize 36, nBands 18) is 13.499531
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png centreline + Angle estimation time at scale 1 =(mSize 54, nBands 18) is 28.730541
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png centreline + Angle estimation time at scale 2 =(mSize 72, nBands 18) is 53.754301
# Centerline extraction time for file T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png is 0.498925
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png centreline + Angle estimation time at scale 0 =(mSize 36, nBands 18) is 15.518163
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png centreline + Angle estimation time at scale 1 =(mSize 54, nBands 18) is 33.744901
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png centreline + Angle estimation time at scale 2 =(mSize 72, nBands 18) is 62.320082
# Total number of pixels on the centerline is = 1429
# The circular mean and variance are -180.0 and 0.0 respectively.
# Total number of pixels on the centerline is = 1429
# The circular mean and variance are -180.0 and 0.0 respectively.
# Total number of pixels on the centerline is = 1429
# The circular mean and variance are -180.0 and 0.0 respectively.
# Total number of pixels on the centerline is = 1189
# The circular mean and variance are -180.0 and 0.0 respectively.
# Total number of pixels on the centerline is = 1189
# The circular mean and variance are -180.0 and 0.0 respectively.
# Total number of pixels on the centerline is = 1189
# The circular mean and variance are -180.0 and 0.0 respectively.
# Total number of pixels on the centerline is = 740
# The circular mean and variance are -180.0 and 0.0 respectively.
# Total number of pixels on the centerline is = 740
# The circular mean and variance are -180.0 and 0.0 respectively.
# Total number of pixels on the centerline is = 740
# The circular mean and variance are -180.0 and 0.0 respectively.
# Total number of pixels on the centerline is = 695
# The circular mean and variance are -180.0 and 0.0 respectively.
# Total number of pixels on the centerline is = 695
# The circular mean and variance are -180.0 and 0.0 respectively.
# Total number of pixels on the centerline is = 695
# The circular mean and variance are -180.0 and 0.0 respectively.
# Total probability = 1.0
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure klDiv calculation time at scale 0 =(mSize 36, nBands 18) is 0.000820000000033
# At scale 0, bands = 18, size = 36  measure based on function klDiv is 0.0202027073175
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure klDiv calculation time at scale 1 =(mSize 54, nBands 18) is 0.000771999999984
# At scale 1, bands = 18, size = 54  measure based on function klDiv is 0.0202027073175
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure klDiv calculation time at scale 2 =(mSize 72, nBands 18) is 0.000744999999995
# At scale 2, bands = 18, size = 72  measure based on function klDiv is 0.0202027073175
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure klDiv calculation time at scale 0 =(mSize 36, nBands 18) is 0.000823000000025
# At scale 0, bands = 18, size = 36  measure based on function klDiv is 0.0202027073175
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure klDiv calculation time at scale 1 =(mSize 54, nBands 18) is 0.00075899999996
# At scale 1, bands = 18, size = 54  measure based on function klDiv is 0.0202027073175
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure klDiv calculation time at scale 2 =(mSize 72, nBands 18) is 0.000753999999972
# At scale 2, bands = 18, size = 72  measure based on function klDiv is 0.0202027073175
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure klDiv calculation time at scale 0 =(mSize 36, nBands 18) is 0.000824000000023
# At scale 0, bands = 18, size = 36  measure based on function klDiv is 0.0202027073175
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure klDiv calculation time at scale 1 =(mSize 54, nBands 18) is 0.000752999999975
# At scale 1, bands = 18, size = 54  measure based on function klDiv is 0.0202027073175
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure klDiv calculation time at scale 2 =(mSize 72, nBands 18) is 0.000744999999995
# At scale 2, bands = 18, size = 72  measure based on function klDiv is 0.0202027073175
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure klDiv calculation time at scale 0 =(mSize 36, nBands 18) is 0.000813999999991
# At scale 0, bands = 18, size = 36  measure based on function klDiv is 0.0202027073175
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure klDiv calculation time at scale 1 =(mSize 54, nBands 18) is 0.00075899999996
# At scale 1, bands = 18, size = 54  measure based on function klDiv is 0.0202027073175
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure klDiv calculation time at scale 2 =(mSize 72, nBands 18) is 0.000788999999997
# At scale 2, bands = 18, size = 72  measure based on function klDiv is 0.0202027073175
# [[0.020202707317519469, 0.020202707317519469, 0.020202707317519469], [0.020202707317519469, 0.020202707317519469, 0.020202707317519469], [0.020202707317519469, 0.020202707317519469, 0.020202707317519469], [0.020202707317519469, 0.020202707317519469, 0.020202707317519469]]
# Total probability = 1.0
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure emdDist calculation time at scale 0 =(mSize 36, nBands 18) is 0.00273200000004
# At scale 0, bands = 18, size = 36  measure based on function emdDist is 0.95256
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure emdDist calculation time at scale 1 =(mSize 54, nBands 18) is 0.00259199999999
# At scale 1, bands = 18, size = 54  measure based on function emdDist is 0.95256
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure emdDist calculation time at scale 2 =(mSize 72, nBands 18) is 0.002476
# At scale 2, bands = 18, size = 72  measure based on function emdDist is 0.95256
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure emdDist calculation time at scale 0 =(mSize 36, nBands 18) is 0.00273999999996
# At scale 0, bands = 18, size = 36  measure based on function emdDist is 0.95256
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure emdDist calculation time at scale 1 =(mSize 54, nBands 18) is 0.00253200000003
# At scale 1, bands = 18, size = 54  measure based on function emdDist is 0.95256
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure emdDist calculation time at scale 2 =(mSize 72, nBands 18) is 0.00252599999999
# At scale 2, bands = 18, size = 72  measure based on function emdDist is 0.95256
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure emdDist calculation time at scale 0 =(mSize 36, nBands 18) is 0.002771
# At scale 0, bands = 18, size = 36  measure based on function emdDist is 0.95256
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure emdDist calculation time at scale 1 =(mSize 54, nBands 18) is 0.002678
# At scale 1, bands = 18, size = 54  measure based on function emdDist is 0.95256
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure emdDist calculation time at scale 2 =(mSize 72, nBands 18) is 0.00266400000004
# At scale 2, bands = 18, size = 72  measure based on function emdDist is 0.95256
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure emdDist calculation time at scale 0 =(mSize 36, nBands 18) is 0.00335799999999
# At scale 0, bands = 18, size = 36  measure based on function emdDist is 0.95256
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure emdDist calculation time at scale 1 =(mSize 54, nBands 18) is 0.00249299999996
# At scale 1, bands = 18, size = 54  measure based on function emdDist is 0.95256
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure emdDist calculation time at scale 2 =(mSize 72, nBands 18) is 0.00252899999998
# At scale 2, bands = 18, size = 72  measure based on function emdDist is 0.95256
# [[0.9525600000000202, 0.9525600000000202, 0.9525600000000202], [0.9525600000000202, 0.9525600000000202, 0.9525600000000202], [0.9525600000000202, 0.9525600000000202, 0.9525600000000202], [0.9525600000000202, 0.9525600000000202, 0.9525600000000202]]
# Normalized by 45 EMD score are
# [[ 0.021168  0.021168  0.021168]
#  [ 0.021168  0.021168  0.021168]
#  [ 0.021168  0.021168  0.021168]
#  [ 0.021168  0.021168  0.021168]]
# Total probability = 1.0
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure L2Dist calculation time at scale 0 =(mSize 36, nBands 18) is 0.000831000000005
# At scale 0, bands = 18, size = 36  measure based on function L2Dist is 0.0205798302171
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure L2Dist calculation time at scale 1 =(mSize 54, nBands 18) is 0.000777000000028
# At scale 1, bands = 18, size = 54  measure based on function L2Dist is 0.0205798302171
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure L2Dist calculation time at scale 2 =(mSize 72, nBands 18) is 0.000807000000009
# At scale 2, bands = 18, size = 72  measure based on function L2Dist is 0.0205798302171
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure L2Dist calculation time at scale 0 =(mSize 36, nBands 18) is 0.000816999999984
# At scale 0, bands = 18, size = 36  measure based on function L2Dist is 0.0205798302171
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure L2Dist calculation time at scale 1 =(mSize 54, nBands 18) is 0.00079599999998
# At scale 1, bands = 18, size = 54  measure based on function L2Dist is 0.0205798302171
# For File T2_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure L2Dist calculation time at scale 2 =(mSize 72, nBands 18) is 0.000787000000003
# At scale 2, bands = 18, size = 72  measure based on function L2Dist is 0.0205798302171
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure L2Dist calculation time at scale 0 =(mSize 36, nBands 18) is 0.000524999999982
# At scale 0, bands = 18, size = 36  measure based on function L2Dist is 0.0205798302171
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure L2Dist calculation time at scale 1 =(mSize 54, nBands 18) is 0.000493000000006
# At scale 1, bands = 18, size = 54  measure based on function L2Dist is 0.0205798302171
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch1.png measure L2Dist calculation time at scale 2 =(mSize 72, nBands 18) is 0.000490000000013
# At scale 2, bands = 18, size = 72  measure based on function L2Dist is 0.0205798302171
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure L2Dist calculation time at scale 0 =(mSize 36, nBands 18) is 0.000530000000026
# At scale 0, bands = 18, size = 36  measure based on function L2Dist is 0.0205798302171
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure L2Dist calculation time at scale 1 =(mSize 54, nBands 18) is 0.000491000000011
# At scale 1, bands = 18, size = 54  measure based on function L2Dist is 0.0205798302171
# For File T1_AnkyrinGm_CA1_hippocampus_63X_MAXPROJ_Patch2.png measure L2Dist calculation time at scale 2 =(mSize 72, nBands 18) is 0.000490000000013
# At scale 2, bands = 18, size = 72  measure based on function L2Dist is 0.0205798302171
# [[0.020579830217101084, 0.020579830217101084, 0.020579830217101084], [0.020579830217101084, 0.020579830217101084, 0.020579830217101084], [0.020579830217101084, 0.020579830217101084, 0.020579830217101084], [0.020579830217101084, 0.020579830217101084, 0.020579830217101084]]
