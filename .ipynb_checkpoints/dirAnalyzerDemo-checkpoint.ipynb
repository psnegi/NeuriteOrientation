# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = 10,10  # that's default image size for this 
#pylab.rcParams['figure.dpi']=32
# %load_ext autoreload
# %autoreload 2
#run txtFiletoHistogram.py
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#%%timeit -n4 -r1
# %run dirAnalyzerDemo.py
# Out:
# Centerline extraction time for file anglej_1_GOstuSeg.png is 57.53155
# For File anglej_1_GOstuSeg.png centreline + Angle estimation time at scale 0 =(mSize 36, nBands 18) is 245.419112
# For File anglej_1_GOstuSeg.png centreline + Angle estimation time at scale 1 =(mSize 54, nBands 18) is 294.538421
# For File anglej_1_GOstuSeg.png centreline + Angle estimation time at scale 2 =(mSize 72, nBands 18) is 302.132387
# Centerline extraction time for file anglej_4_GOstuSeg.png is 60.512379
# For File anglej_4_GOstuSeg.png centreline + Angle estimation time at scale 0 =(mSize 36, nBands 18) is 298.070934
# For File anglej_4_GOstuSeg.png centreline + Angle estimation time at scale 1 =(mSize 54, nBands 18) is 339.974254
# For File anglej_4_GOstuSeg.png centreline + Angle estimation time at scale 2 =(mSize 72, nBands 18) is 346.883329
# Centerline extraction time for file anglej_5_GOstuSeg.png is 52.242642
# For File anglej_5_GOstuSeg.png centreline + Angle estimation time at scale 0 =(mSize 36, nBands 18) is 255.952015
# For File anglej_5_GOstuSeg.png centreline + Angle estimation time at scale 1 =(mSize 54, nBands 18) is 295.349844
# For File anglej_5_GOstuSeg.png centreline + Angle estimation time at scale 2 =(mSize 72, nBands 18) is 306.872216
# Centerline extraction time for file anglej_6_GOstuSeg.png is 73.678228
# For File anglej_6_GOstuSeg.png centreline + Angle estimation time at scale 0 =(mSize 36, nBands 18) is 305.010545
# For File anglej_6_GOstuSeg.png centreline + Angle estimation time at scale 1 =(mSize 54, nBands 18) is 346.443852
# For File anglej_6_GOstuSeg.png centreline + Angle estimation time at scale 2 =(mSize 72, nBands 18) is 368.518277
# Total number of pixels on the centerline is = 12396
# The circular mean and variance are -177.469301577 and 0.0578486803364 respectively.
# Total number of pixels on the centerline is = 12396
# The circular mean and variance are -177.644387387 and 0.0462553975139 respectively.
# Total number of pixels on the centerline is = 12396
# The circular mean and variance are -177.458627585 and 0.0446539388165 respectively.
# Total number of pixels on the centerline is = 13939
# The circular mean and variance are -177.587021285 and 0.089515748825 respectively.
# Total number of pixels on the centerline is = 13939
# The circular mean and variance are -177.831235425 and 0.0749985811595 respectively.
# Total number of pixels on the centerline is = 13939
# The circular mean and variance are -177.61818334 and 0.0758303759572 respectively.
# Total number of pixels on the centerline is = 13869
# The circular mean and variance are -2.09080058204 and 0.0762157226259 respectively.
# Total number of pixels on the centerline is = 13869
# The circular mean and variance are -1.98197426325 and 0.0634079805166 respectively.
# Total number of pixels on the centerline is = 13869
# The circular mean and variance are -1.84043629416 and 0.0530584268894 respectively.
# Total number of pixels on the centerline is = 21113
# The circular mean and variance are -178.148475281 and 0.147549363568 respectively.
# Total number of pixels on the centerline is = 21113
# The circular mean and variance are -178.179918369 and 0.122694154314 respectively.
# Total number of pixels on the centerline is = 21113
# The circular mean and variance are -178.02035407 and 0.10891269383 respectively.
# Total probability = 1.0
# For File anglej_1_GOstuSeg.png measure klDiv calculation time at scale 0 =(mSize 36, nBands 18) is 0.000986999999895
# At scale 0, bands = 18, size = 36  measure based on function klDiv is 2.17426796956
# For File anglej_1_GOstuSeg.png measure klDiv calculation time at scale 1 =(mSize 54, nBands 18) is 0.000813000000107
# At scale 1, bands = 18, size = 54  measure based on function klDiv is 1.50886281491
# For File anglej_1_GOstuSeg.png measure klDiv calculation time at scale 2 =(mSize 72, nBands 18) is 0.000774000000092
# At scale 2, bands = 18, size = 72  measure based on function klDiv is 1.98709828964
# For File anglej_4_GOstuSeg.png measure klDiv calculation time at scale 0 =(mSize 36, nBands 18) is 0.000815999999759
# At scale 0, bands = 18, size = 36  measure based on function klDiv is 2.503442083
# For File anglej_4_GOstuSeg.png measure klDiv calculation time at scale 1 =(mSize 54, nBands 18) is 0.000793000000158
# At scale 1, bands = 18, size = 54  measure based on function klDiv is 1.57078544482
# For File anglej_4_GOstuSeg.png measure klDiv calculation time at scale 2 =(mSize 72, nBands 18) is 0.000782999999956
# At scale 2, bands = 18, size = 72  measure based on function klDiv is 2.09201728423
# For File anglej_5_GOstuSeg.png measure klDiv calculation time at scale 0 =(mSize 36, nBands 18) is 0.000839999999698
# At scale 0, bands = 18, size = 36  measure based on function klDiv is 2.78739046557
# For File anglej_5_GOstuSeg.png measure klDiv calculation time at scale 1 =(mSize 54, nBands 18) is 0.000830999999835
# At scale 1, bands = 18, size = 54  measure based on function klDiv is